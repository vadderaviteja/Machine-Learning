# %% [markdown]
# # Ensemble learning

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\Pictures\Screenshots\Screenshot 2024-11-15 131913.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=864x379>

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\Pictures\Screenshots\Screenshot 2024-11-15 132048.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=842x416>

# %%
### types of ensemble learning:
1.Bagging(Bootstrap Aggregation)
2.Boosting
3.stacking
4.cascading

# %% [markdown]
# # 1.Bagging(Bootstrap Aggregation)
# In Bagging , we take different subsets of dataset randomly and combine them with the help pf bootstrap sampling.On detail,, given a training data set containing the n number od trainig examples , a sample of 'm' training examples will be generated by samplin with replacement.In bagging we used the n=most popular strategies for aggregating th eoutputs of the base learners, that is , fiinid out hte majority vote in a classification task and findiing tj=he mean in the regression task.
#
#
# ##### or
# Bootstrap Aggregation, commonly known as Bagging, is an ensemble machine learning technique designed to improve the accuracy and stability of models by reducing overfitting and variance. It works by combining the predictions of multiple models trained on different subsets of the data.
#
# How Bagging Works
# Bootstrapping the Data:
#
# The original dataset is randomly sampled with replacement to create multiple training subsets (called bootstrap samples).
# Each bootstrap sample may include duplicate entries since sampling is with replacement, and it will typically be of the same size as the original dataset.
# Training Multiple Models:
#
# Independent models are trained on each of the bootstrap samples.
# These models are often of the same type (e.g., decision trees).
# Aggregating Predictions:
#
# For regression tasks: The predictions from all models are averaged.
# For classification tasks: A majority voting system determines the final prediction.

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\Pictures\Screenshots\Screenshot 2024-11-15 133709.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=594x451>

# %% [markdown]
# In bagging, we actauly combine several strong learners in which all the base models are overfitted models they are having a very high variance and at the time of aggragation we simply try to reduce that variance withiut affecting the bias with which the accuracy may approve.

# %% [markdown]
# # Boosting
# Boostnig is a kind of algorithm that is able to convert weak learners to strong learners .In a boosting techique , each alg that is base learners are trained sequentiallly and at every time the next learners i strying to redi=uce the error by updating the parameters and perform better in comparision to the previous learners.
#
# Boosting works by training a different set of learners sequentialll\y and combining them for prediction , where the lerners focuses more on the mistakes of the earlier(previous) learners.
#
# #### Types:
# ##### 1.ADA Boost()
# ##### 2.Gradient Boosting
# ##### 3.XG Boost (Extreme Gradient Boost)

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\Pictures\Screenshots\Screenshot 2024-11-15 135734.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=866x425>

# %% [markdown]
# # Stacking
# Stacking is an learning methods that combines multiple machine learning alg via meta-learning, In which base-level alg are trained based on a complete training data-set, them meta-model is trained on the final outcomes of all base-level model as a feature. we have to deal with bagging and boostiing methods for handling bias and variance. stacking to improve model prediction accuracy

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\Pictures\Screenshots\Screenshot 2024-11-15 135919.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=409x507>

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\Pictures\Screenshots\Screenshot 2024-11-15 140136.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=533x502>

# %% [markdown]
# # 1.Hard votiing
# # 2.Soft Voting
# ### Hard votiing
# Hard voting is the simplest casse of majority voting. In this case, the class that received the highest number of votes will be chosen.
# ### Soft Voting
# ##### 1Averaging
# ##### 2.weighted Averaging

# %%
#
from PIL import Image
Image.open(r"C:\Users\Windows\Pictures\Screenshots\Screenshot 2024-11-15 193018.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=862x473>

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\Pictures\Screenshots\Screenshot 2024-11-15 193037.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=895x359>

# %% [markdown]
# ### Final Outcomes
#       ####  Type                                    ##### use
#       1. Bagging/parallelensemble learning   ------>Decrease Variance
#       2.Boosting/sequential Ensemble         ------>Reduce the Bias
#       3.Stacking                             ------>Improve predictions
