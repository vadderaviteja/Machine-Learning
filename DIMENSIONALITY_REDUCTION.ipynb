# %% [markdown]
# # Dimensionality Reduction

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\OneDrive\Pictures\Screenshots\Screenshot 2025-03-15 130002.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=777x283>

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\OneDrive\Pictures\Screenshots\Screenshot 2025-03-15 130021.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=846x207>

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\OneDrive\Pictures\Screenshots\Screenshot 2025-03-15 130038.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=650x207>

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\OneDrive\Pictures\Screenshots\Screenshot 2025-03-15 130054.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=806x327>

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\OneDrive\Pictures\Screenshots\Screenshot 2025-03-15 130112.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=709x348>

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\OneDrive\Pictures\Screenshots\Screenshot 2025-03-15 130800.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=769x378>

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\OneDrive\Pictures\Screenshots\Screenshot 2025-03-15 130147.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=736x387>

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\OneDrive\Pictures\Screenshots\Screenshot 2025-03-15 130207.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=763x420>

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\OneDrive\Pictures\Screenshots\Screenshot 2025-03-15 130224.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=744x236>

# %%
from PIL import Image
Image.open(r"C:\Users\Windows\OneDrive\Pictures\Screenshots\Screenshot 2025-03-15 130239.png")
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=698x263>

# %%
from PIL import Image
Image.open(r)

# %%
from PIL import Image
Image.open(r)

# %%
from PIL import Image
Image.open(r)

# %%
from PIL import Image
Image.open(r)

# %%
from PIL import Image
Image.open(r)

# %%
from PIL import Image
Image.open(r)

# %%
from PIL import Image
Image.open(r)
